# %%
# %matplotlib inline
import pandas as pd

ddir = './data/'

# %% [markdown]
# ## DataFrame

# %%
df = pd.read_csv(ddir + 'IceOut_RL.txt')

# %%
wdata = pd.read_csv(ddir + '893229.csv')
wdata['TMAX'].plot()

# %%
import quandl
quandl.ApiConfig.api_key = 'xb1exKWPtyQvpbfqCZsB'
data = quandl.get("CHRIS/CME_CL1")
# Out:
# Date
# 1983-03-30    29.40
# 1983-03-31    29.29
# 1983-04-04    29.44
# 1983-04-05    29.71
# 1983-04-06    29.90
# 1983-04-07    30.17
# 1983-04-08    30.38
# 1983-04-11    30.26
# 1983-04-12    30.83
# 1983-04-13    30.82
# 1983-04-14    30.69
# 1983-04-15    30.48
# 1983-04-18    30.75
# 1983-04-19    30.75
# 1983-04-20    30.70
# 1983-04-21    30.68
# 1983-04-22    30.75
# 1983-04-25    30.84
# 1983-04-26    30.71
# 1983-04-27    30.78
# 1983-04-28    30.74
# 1983-04-29    30.63
# 1983-05-02    30.61
# 1983-05-03    30.50
# 1983-05-04    30.42
# 1983-05-05    30.20
# 1983-05-06    30.45
# 1983-05-09    30.10
# 1983-05-10    30.31
# 1983-05-11    29.97
#               ...
# 2017-01-26    53.78
# 2017-01-27    53.17
# 2017-01-30    52.63
# 2017-01-31    52.81
# 2017-02-01    53.88
# 2017-02-02    53.54
# 2017-02-03    53.83
# 2017-02-06    53.01
# 2017-02-07    52.17
# 2017-02-08    52.34
# 2017-02-09    53.00
# 2017-02-10    53.86
# 2017-02-13    52.93
# 2017-02-14    53.20
# ...

# %%
cl = data['Settle']

# %%
import pandas_datareader.data as web

aapl = web.DataReader('AAPL', 'yahoo')['Adj Close']

# %%
cl.plot()
aapl.plot()

# %%
df = pd.concat([cl,aapl],axis=1)
df.columns=['Oil','Apple']

# %%
import numpy as np

df = df[np.isfinite(df['Apple'])]

# %%
import seaborn as sns
sns.set_context('talk')
df.plot()

# %%
import matplotlib.pyplot as plt

ax = plt.subplot2grid((2,2),(0, 0),rowspan=2)

plt.scatter(df['2010':]['Oil'],df['2010':]['Apple'],marker='.',alpha=0.5)
plt.xlabel('Oil')
plt.ylabel('Apple')

plt.subplot2grid((2,2),(0,1))
aapl['2010':].plot()

plt.subplot2grid((2,2),(1,1))
cl['2010':].plot()
plt.title('Oil')

plt.tight_layout()

# %%
r = aapl.diff()/aapl

# %%
# %matplotlib notebook
r.plot()
# Out:
# <img src="data:image/png;base64,..." width="432">
